# %% [markdown]
# <a href="https://colab.research.google.com/github/Maniganiga404/python-practice/blob/main/Pythonday5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Python day 5
for m in range(1,6):
  for n in range(1,m+1):
    print(n,end='')
  print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %%
for m in range(1,6):
  for n in range(1,m+1):
    print(m,end='')
  print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %%
for m in range(1,6):
  for n in range(m,0,-1):
    print(n,end='')
  print()
# Out:
# 1
# 21
# 321
# 4321
# 54321

# %%
for m in range(1,6):
  for n in range(1,m+1):
    print('*',end='')
  print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for m in range(5,0,-1):
  for n in range(1,m+1):
    print('*',end='')
  print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for m in range(1,6):
  for n in range(1,m+1):
    print(n,end='')
  print()
for m in range(5,0,-1):
  for n in range(1,m+1):
    print(n,end='')
  print()
# Out:
# 1
# 12
# 123
# 1234
# 12345
# 12345
# 1234
# 123
# 12
# 1

# %%
for m in range(1,6):
  print(m,end=' ')
# Out:
# 1 2 3 4 5

# %%
for m in range(1,10):
  if m==6:
    break
  print(m)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#continue
for m in range(1,11):
  if m==5:
    continue
  print(m)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
#Print odd numbers and stop at 15
for m in range(1,20):
  if m%2==0:
    continue
  if m==15:
    break
  print(m)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
