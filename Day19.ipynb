# %% [markdown]
# <a href="https://colab.research.google.com/github/Maniganiga404/python-practice/blob/main/Day19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Day19.ipynb_

[ ]
#Day19# Create a decorator called log_function that prints:# Function started# then runs the original function, then prints:# Function finisheddef decorator(func):  def log_functions(*args,**kwargs):    print("function started")    result = func(*args,**kwargs)    print("function finished")    return result  return log_functions@decoratordef greet(name):  print("Hello",name)greet("Manish")

 function started
Hello Manish
function finished

[ ]
#Constructordef multiplier(x):    def multiply(y):        return x * y    return multiplydouble = multiplier(2)triple = multiplier(3)print(double(10))print(triple(10))

 20
30

[1]
#CONTEXT MANAGER
class MyContext:

    def __enter__(self):
        print("Entering the context")

    def __exit__(self, exc_type, exc_value, traceback):
        print("Leaving the context")

 Entering the context
Inside the context
Leaving the context

[3]
0s
class MyContext:

  def __enter__(self):
    print("Resource Opened")
    return self;

  def __exit__(self, exc_type, exc_value, traceback):
    print("Resource Closed")

with MyContext() as obj:
  print("Using resource")

 Resource Opened
Using resource
Resource Closed

[4]
#will show us error but still perform cleanup
class MyContext:

    def __enter__(self):
        print("Starting")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        print("Ending")
        print("Type:", exc_type)
        print("Value:", exc_value)

with MyContext():
    print(10 / 0)

Next steps:

[6]
#creating exception handlers
class InvalidAgeError(Exception):
    pass

age = -5

if age < 0:
    raise InvalidAgeError("Age cannot be negative")

Next steps:

[7]
0s
try:
    age = -5

    if age < 0:
        raise InvalidAgeError("Age cannot be negative")

except InvalidAgeError as e:
    print(e)
 Age cannot be negative

[9]
0s
#Practice problems
# Write a function called student_info that accepts any number of positional and keyword arguments.
# For:
# student_info("Manish", 20, course="Python", level="Beginner")
# it should print:
# Positional: ('Manish', 20)
# Keyword: {'course': 'Python', 'level': 'Beginner'}

def student_info(*args, **kwargs):
    print("Positional:", args)
    print("Keyword:", kwargs)

student_info("Manish", 20, course="Python", level="Beginner")
 Positional: ('Manish', 20)
Keyword: {'course': 'Python', 'level': 'Beginner'}

[13]
0s
# Write a function:
# divide(a, b)
# Requirements:
# Try to divide a / b
# If b is 0, catch ZeroDivisionError
# Print "Cannot divide by zero"
# Use finally to print "Done"

def divide(a,b):
    try:
      result = a/b

    except ZeroDivisionError:
      print("Cannot divide by zero")

    finally:
      print("Done")

divide(10,0)

 Cannot divide by zero
Done

[15]
0s
# Create:
# class MyContext:
# It should:
# __enter__() print "Starting"
# __exit__() print "Ending"
# If an error happens inside the with block, print "Error occurred"
# If there is no error, just print "Ending"
# Test it with:
# with MyContext():
#     print("Working")

class MyContext:
    def __enter__(self):
        print("Starting")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            print("Error occurred")
        print("Ending")


with MyContext():
    print("Working")

 Starting
Working
Ending
Colab paid products
-
Cancel contracts here
z = MyContext() with z: print("Inside the context")
