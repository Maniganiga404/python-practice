# %% [markdown]
# <a href="https://colab.research.google.com/github/Maniganiga404/python-practice/blob/main/Day14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Day14
#Write a program that takes a number as input. If the number is negative, use raise to generate
number = int(input("enter your number:"))

if number < 0:
  raise ValueError("Number cannot be negative")

print("Valid number")
# Out:
# enter your number:1
# Valid number

# %%
file = open("student.txt", "w")
file.write("Manish\nRahul\nArjun")
file.close()

file = open("student.txt","r")

content = file.read()

print(content)

file.close()
# Out:
# Manish
# Rahul
# Arjun

# %%
#Write a program that creates/overwrites student.txt and stores:

file = open("student.txt","w")

file.write("Manish\n Python\n Day14")

file.close()

file = open("student.txt", "r")

content = file.read()

print(content)

file.close()
# Out:
# Manish
#  Python
#  Day14

# %%
#Write code that appends these two lines to your existing student.txt:

file = open("student.txt","a")

file.write("\nException Handling")

file.write("\nFile Handling")

file.close()

# %%
#Opens student.txt using with open()
# Reads the entire file
# Prints the contents
# Do not use file.close()

with open("student.txt","r") as file:
  content = file.read()
  print(content)
# Out:
# Manish
#  Python
#  Day14
# Exception Handling
# File Handling
