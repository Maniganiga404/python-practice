# %% [markdown]
# <a href="https://colab.research.google.com/github/Maniganiga404/python-practice/blob/main/Day15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Day 15
#The length of the list
#The sum of all numbers
#The maximum number
#The minimum number
#The absolute value of -15
#21 rounded to 2 decimal places


numbers = [12, -5, 8, 21, -15, 4]

print(len(numbers))

print(sum(numbers))

print(max(numbers))

print(min(numbers))

print(abs(numbers[4]))

print(round(numbers[3],2))
# Out:
# 6
# 25
# 21
# -15
# 15
# 21

# %%
# Modeules

# import math

# from math import sqrt

# import math as m



# own Modeules


# Built-in functions


# abs()-distance from zero

# round()-rounds off to decimal points

# max()-largest numbers

# min()-samallest number

# sum()-adds all numbers

# len()-gives length of items or string

# enumerate()- gives index and ValueError

# zip()-combines items from 2 iterables
